# %% [markdown]
# # NYC Major Events Dataset (2022-2024)
#
# Creating a clean dataset with 5 major NYC events for analysis.

# %%
# Import libraries
from sodapy import Socrata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Set plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 8)

# %%
# Initialize API client
client = Socrata("data.cityofnewyork.us", None, timeout=120)

# Load Events Data for 2022-2024
print("📥 Loading Events Data (2022-2024)...")

events_results = client.get(
    "bkfu-528j",  # NYC Events dataset
    where="start_date_time >= '2022-01-01T00:00:00.000' AND start_date_time < '2025-01-01T00:00:00.000'",
    limit=100000
)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# 📥 Loading Events Data (2022-2024)...

# %%
import pandas as pd

df_events = pd.DataFrame.from_records(events_results)
print(f"✅ Loaded {len(df_events):,} event records")

# Process dates
if "start_date_time" in df_events.columns:
    df_events["start_date_time"] = pd.to_datetime(df_events["start_date_time"], errors="coerce")
    
    # Show date range and year distribution
    print(f"📅 Date Range: {df_events['start_date_time'].min()} to {df_events['start_date_time'].max()}")
    print(f"📊 Year Distribution:")
    event_year_counts = df_events['start_date_time'].dt.year.value_counts().sort_index()
    for year, count in event_year_counts.items():
        print(f"   • {year}: {count:,} events")

if "end_date_time" in df_events.columns:
    df_events["end_date_time"] = pd.to_datetime(df_events["end_date_time"], errors="coerce")

print(f"\n🎯 Final Datasets:")
print(f"   • Arrests (Target Crimes): {len(df_arrests_filtered):,} records")
print(f"   • Events (All Types): {len(df_events):,} records")
# Out:
# ✅ Loaded 100,000 event records
# 📅 Date Range: 2022-01-01 00:00:00 to 2022-02-02 11:30:00
# 📊 Year Distribution:
#    • 2022: 100,000 events
#
# 🎯 Final Datasets:
#    • Arrests (Target Crimes): 191,409 records
#    • Events (All Types): 100,000 records

# %%
# Filter for 5 Major NYC Events
print("🎯 Filtering for 5 Major NYC Events...")

# Define 5 major events to track
major_events_keywords = {
    'US Open Tennis': ['us open', 'tennis'],
    'NYC Marathon': ['marathon', 'new york city marathon', 'tcs new york'],
    'Pride March': ['pride', 'lgbt', 'lgbtq'],
    'Thanksgiving Parade': ['thanksgiving', 'macy'],
    'New Year\'s Eve': ['new year', 'times square', 'ball drop']
}

# Function to check if event matches any major event
def is_major_event(event_name):
    if pd.isna(event_name):
        return None
    event_name_lower = event_name.lower()
    
    for event_category, keywords in major_events_keywords.items():
        if any(keyword in event_name_lower for keyword in keywords):
            return event_category
    return None

# Apply filter
df_events['major_event_category'] = df_events['event_name'].apply(is_major_event)
df_events_major = df_events[df_events['major_event_category'].notna()].copy()

print(f"✅ Filtered to {len(df_events_major):,} events (from {len(df_events):,} total)")
print(f"\n📊 Events by Category:")
for event, count in df_events_major['major_event_category'].value_counts().items():
    print(f"   • {event}: {count:,} events")
# Out:
# 🎯 Filtering for 5 Major NYC Events...
# ✅ Filtered to 163 events (from 100,000 total)
#
# 📊 Events by Category:
#    • New Year's Eve: 115 events
#    • NYC Marathon: 48 events
# ✅ Filtered to 163 events (from 100,000 total)
#
# 📊 Events by Category:
#    • New Year's Eve: 115 events
#    • NYC Marathon: 48 events

# %%
# Deduplicate: Keep only one event per category per day
print(f"\n🔧 Deduplicating events...")
print(f"   Before: {len(df_events_major):,} events")

# Create date field (without time)
df_events_major['event_date'] = df_events_major['start_date_time'].dt.date

# Keep only first event per category per day
df_events_major = df_events_major.drop_duplicates(
    subset=['major_event_category', 'event_date'],
    keep='first'
).reset_index(drop=True)

print(f"   After: {len(df_events_major):,} unique events")
print(f"\n✅ Final Event Counts:")
for event, count in df_events_major['major_event_category'].value_counts().items():
    print(f"   • {event}: {count:,} events")
# Out:
# 🔧 Deduplicating events...
#    Before: 163 events
#    After: 16 unique events
#
# ✅ Final Event Counts:
#    • New Year's Eve: 12 events
#    • NYC Marathon: 4 events

# %%
# Display Final DataFrame
print("\n" + "="*80)
print("📋 FINAL MAJOR EVENTS DATAFRAME")
print("="*80)
print(f"\nShape: {df_events_major.shape}")
print(f"Columns: {list(df_events_major.columns)}\n")

df_events_major
# Out:
# ================================================================================
# 📋 FINAL MAJOR EVENTS DATAFRAME
# ================================================================================
#
# Shape: (16, 14)
# Columns: ['event_id', 'event_name', 'start_date_time', 'end_date_time', 'event_agency', 'event_type', 'event_borough', 'event_location', 'street_closure_type', 'community_board', 'police_precinct', 'event_street_side', 'major_event_category', 'event_date']
#    event_id                                   event_name     start_date_time  \
# 0    609882                     New Year's Eve 2021-2022 2022-01-01 00:00:00
# 1    609641         Sri Chinmoy New Year's Half Marathon 2022-01-01 08:00:00
# 2    609882                     New Year's Eve 2021-2022 2022-01-02 00:00:00
# 3    609882                     New Year's Eve 2021-2022 2022-01-03 00:00:00
# 4    609882                     New Year's Eve 2021-2022 2022-01-04 00:00:00
# 5    611955                        CDP Marathon Protests 2022-01-04 13:30:00
# 6    609882                     New Year's Eve 2021-2022 2022-01-05 00:00:00
# 7    609882                     New Year's Eve 2021-2022 2022-01-06 00:00:00
# 8    609882                     New Year's Eve 2021-2022 2022-01-07 00:00:00
# 9    610003  NYCRUNS Frozen Penguin Half Marathon and 5K 2022-01-09 05:00:00
# 10   621256               Panda Express - Lunar New Year 2022-01-29 00:01:00
# 11   610207            2022 Times Square Valentine Heart 2022-01-30 00:00:00
# 12   610207            2022 Times Square Valentine Heart 2022-01-31 00:00:00
# 13   610207            2022 Times Square Valentine Heart 2022-02-01 00:00:00
# 14   611962                        CDP Marathon Protests 2022-02-01 13:30:00
# 15   610207            2022 Times Square Valentine Heart 2022-02-02 00:00:00
#
#          end_date_time                   event_agency     event_type  \
# 0  2022-01-01 23:59:00               Parks Department  Special Event
# 1  2022-01-01 12:00:00               Parks Department  Special Event
# 2  2022-01-02 23:59:00               Parks Department  Special Event
# 3  2022-01-03 23:59:00               Parks Department  Special Event
# 4  2022-01-04 23:59:00               Parks Department  Special Event
# 5  2022-01-04 15:00:00               Parks Department  Special Event
# 6  2022-01-05 23:59:00               Parks Department  Special Event
# 7  2022-01-06 23:59:00               Parks Department  Special Event
# 8  2022-01-07 23:59:00               Parks Department  Special Event
# 9  2022-01-09 12:30:00               Parks Department  Special Event
# 10 2022-02-01 23:59:00  Street Activity Permit Office   Street Event
# 11 2022-01-30 23:59:00               Parks Department  Special Event
# 12 2022-01-31 23:59:00               Parks Department  Special Event
# 13 2022-02-01 23:59:00               Parks Department  Special Event
# 14 2022-02-01 15:00:00               Parks Department  Special Event
# 15 2022-02-02 23:59:00               Parks Department  Special Event
#
#    event_borough                                     event_location  \
# 0      Manhattan           Father Duffy Square: Father Duffy Square
# 1         Queens       Flushing Meadows Corona Park: Ederle Terrace
# 2      Manhattan           Father Duffy Square: Father Duffy Square
# 3      Manhattan           Father Duffy Square: Father Duffy Square
# 4      Manhattan           Father Duffy Square: Father Duffy Square
# 5      Manhattan         Dag Hammarskjold Plaza: First Avenue Plaza
# 6      Manhattan           Father Duffy Square: Father Duffy Square
# 7      Manhattan           Father Duffy Square: Father Duffy Square
# 8      Manhattan           Father Duffy Square: Father Duffy Square
# 9      Manhattan  Central Park: 102nd Street Transverse ,Central...
# 10      Brooklyn  FULTON STREET between PEARL STREET and JAY STR...
# 11     Manhattan           Father Duffy Square: Father Duffy Square
# 12     Manhattan           Father Duffy Square: Father Duffy Square
# 13     Manhattan           Father Duffy Square: Father Duffy Square
# 14     Manhattan         Dag Hammarskjold Plaza: First Avenue Plaza
# 15     Manhattan           Father Duffy Square: Father Duffy Square
#
#          street_closure_type community_board police_precinct  \
# 0                        N/A              5,             18,
# 1                        N/A             81,            110,
# 2                        N/A              5,             18,
# 3                        N/A              5,             18,
# 4                        N/A              5,             18,
# 5                        N/A              6,             17,
# 6                        N/A              5,             18,
# 7                        N/A              5,             18,
# 8                        N/A              5,             18,
# 9                        N/A             64,             22,
# 10  Partial Sidewalk Closure              2,             84,
# 11                       N/A              5,             18,
# 12                       N/A              5,             18,
# 13                       N/A              5,             18,
# 14                       N/A              6,             17,
# 15                       N/A              5,             18,
#
#    event_street_side major_event_category  event_date
# 0                NaN       New Year's Eve  2022-01-01
# 1                NaN         NYC Marathon  2022-01-01
# 2                NaN       New Year's Eve  2022-01-02
# 3                NaN       New Year's Eve  2022-01-03
# 4                NaN       New Year's Eve  2022-01-04
# 5                NaN         NYC Marathon  2022-01-04
# 6                NaN       New Year's Eve  2022-01-05
# 7                NaN       New Year's Eve  2022-01-06
# 8                NaN       New Year's Eve  2022-01-07
# 9                NaN         NYC Marathon  2022-01-09
# 10             North       New Year's Eve  2022-01-29
# 11               NaN       New Year's Eve  2022-01-30
# 12               NaN       New Year's Eve  2022-01-31
# 13               NaN       New Year's Eve  2022-02-01
# 14               NaN         NYC Marathon  2022-02-01
# 15               NaN       New Year's Eve  2022-02-02

# %%
# Save to CSV
output_file = "major_events_final.csv"
df_events_major.to_csv(output_file, index=False)
print(f"✅ DataFrame saved to: {output_file}")
print(f"   Total events: {len(df_events_major):,}")
# Out:
# ✅ DataFrame saved to: major_events_final.csv
#    Total events: 16
