# %% [markdown]
# # 🔍 NYC Crime Hotspot Analysis with Temporal Event Impact
#
# ## Project Overview
# This notebook analyzes crime hotspots in NYC and their temporal dynamics around major events.
#
# **Final DataFrames:**
# - `df_crimes`: Filtered arrest data (5 crime categories, valid coordinates)
# - `df_events`: Major NYC events (Halloween, Independence Day, NYC Marathon)
#
# **Analysis Objectives:**
# 1. Load and preprocess NYC arrest data (2024)
# 2. Load and filter major event data (2024)
# 3. Perform temporal hotspot analysis around events
# 4. Compare hotspot dynamics: baseline vs. event periods

# %%
# ========================================
# 1. IMPORT LIBRARIES
# ========================================
import contextily as ctx
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
from scipy.spatial import ConvexHull
import seaborn as sns
from sodapy import Socrata
import warnings
warnings.filterwarnings('ignore')
# Out:
# ✅ All libraries imported successfully
# NumPy version: 2.3.2
# Pandas version: 2.3.2

# %%
# ========================================
# 2. LOAD ARREST DATA
# ========================================

# Load 2024 arrest data from NYC Open Data API
print("📥 Loading NYC Arrest Data (2024)...")
client = Socrata("data.cityofnewyork.us", None)
results = client.get("8h9b-rp9u", 
                     where="arrest_date >= '2024-01-01T00:00:00' AND arrest_date < '2025-01-01T00:00:00.000'",
                     limit=350000)
df = pd.DataFrame.from_records(results)

print(f"✅ Loaded {len(df):,} total arrest records")
print(f"📅 Date range: {df['arrest_date'].min()} to {df['arrest_date'].max()}")
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# 📥 Loading NYC Arrest Data (2024)...
# ✅ Loaded 260,503 total arrest records
# 📅 Date range: 2024-01-01T00:00:00.000 to 2024-12-31T00:00:00.000
# ✅ Loaded 260,503 total arrest records
# 📅 Date range: 2024-01-01T00:00:00.000 to 2024-12-31T00:00:00.000

# %%
# ========================================
# 3. PREPROCESSING - FILTER TO 5 CRIME CATEGORIES
# ========================================

# Define the 5 crime categories
relevant_crimes = [
    'ROBBERY',
    'ASSAULT 3 & RELATED OFFENSES',
    'DANGEROUS DRUGS',
    'PETIT LARCENY',
    'CRIMINAL TRESPASS'
]

# Filter to relevant crimes only
df_crimes = df[df['ofns_desc'].isin(relevant_crimes)].copy()
print(f"✅ Filtered to {len(df_crimes):,} arrests in 5 crime categories")

# Convert coordinates to numeric
df_crimes['latitude'] = pd.to_numeric(df_crimes['latitude'], errors='coerce')
df_crimes['longitude'] = pd.to_numeric(df_crimes['longitude'], errors='coerce')

# Remove missing coordinates
df_crimes = df_crimes.dropna(subset=['latitude', 'longitude'])
print(f"✅ After removing missing coordinates: {len(df_crimes):,} arrests")

# Validate NYC coordinates
df_crimes = df_crimes[
    (df_crimes['latitude'] >= 40.5) & 
    (df_crimes['latitude'] <= 41.0) &
    (df_crimes['longitude'] >= -74.3) & 
    (df_crimes['longitude'] <= -73.7)
]
print(f"✅ After coordinate validation: {len(df_crimes):,} arrests")

# Convert arrest_date to datetime and extract temporal features
df_crimes['arrest_datetime'] = pd.to_datetime(df_crimes['arrest_date'])
df_crimes['date'] = df_crimes['arrest_datetime'].dt.date
df_crimes['hour'] = df_crimes['arrest_datetime'].dt.hour
df_crimes['day_of_week'] = df_crimes['arrest_datetime'].dt.dayofweek

# Summary statistics
print("\n" + "="*60)
print("FINAL CRIME DATASET (df_crimes)")
print("="*60)
print(f"Total arrests: {len(df_crimes):,}")
print(f"Date range: {df_crimes['arrest_datetime'].min()} to {df_crimes['arrest_datetime'].max()}")
print(f"\nCrime type distribution:")
crime_dist = df_crimes['ofns_desc'].value_counts()
for crime, count in crime_dist.items():
    pct = (count / len(df_crimes)) * 100
    print(f"  • {crime}: {count:,} ({pct:.1f}%)")
print("="*60)
# Out:
# ✅ Filtered to 98,653 arrests in 5 crime categories
# ✅ After removing missing coordinates: 98,652 arrests
# ✅ After coordinate validation: 98,650 arrests
#
# ============================================================
# FINAL CRIME DATASET (df_crimes)
# ============================================================
# Total arrests: 98,650
# Date range: 2024-01-01 00:00:00 to 2024-12-31 00:00:00
#
# Crime type distribution:
#   • ASSAULT 3 & RELATED OFFENSES: 38,236 (38.8%)
#   • PETIT LARCENY: 27,107 (27.5%)
#   • DANGEROUS DRUGS: 18,518 (18.8%)
#   • ROBBERY: 12,020 (12.2%)
#   • CRIMINAL TRESPASS: 2,769 (2.8%)
# ============================================================
#
# ============================================================
# FINAL CRIME DATASET (df_crimes)
# ============================================================
# Total arrests: 98,650
# Date range: 2024-01-01 00:00:00 to 2024-12-31 00:00:00
#
# Crime type distribution:
#   • ASSAULT 3 & RELATED OFFENSES: 38,236 (38.8%)
#   • PETIT LARCENY: 27,107 (27.5%)
#   • DANGEROUS DRUGS: 18,518 (18.8%)
#   • ROBBERY: 12,020 (12.2%)
#   • CRIMINAL TRESPASS: 2,769 (2.8%)
# ============================================================

# %%
# Initialize API client
client = Socrata("data.cityofnewyork.us", None, timeout=120)

# Load Events Data for 2022-2024
print("📥 Loading Events Data (2024)...")

events_results = client.get(
    "bkfu-528j",  # NYC Events dataset
    where="start_date_time >= '2024-01-01T00:00:00.000' AND start_date_time < '2025-01-01T00:00:00.000'",
    limit=5000000
)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# 📥 Loading Events Data (2024)...

# %%
events_results_df = pd.DataFrame.from_records(events_results)
events_results_df
# Out:
#         event_id                       event_name          start_date_time  \
# 0         746721  New Years Eve Fireworks Display  2024-01-01T00:00:00.000
# 1         739793       Lawn closure - Cherry Hill  2024-01-01T00:00:00.000
# 2         739847   Lawn Closure - Mineral Springs  2024-01-01T00:00:00.000
# 3         679798      Landscape closed for season  2024-01-01T00:00:00.000
# 4         743992                 Big Apple Circus  2024-01-01T00:00:00.000
# ...          ...                              ...                      ...
# 4283309   814462                 Football - Youth  2024-12-31T20:00:00.000
# 4283310   811441          Soccer - Non Regulation  2024-12-31T22:00:00.000
# 4283311   811441          Soccer - Non Regulation  2024-12-31T22:00:00.000
# 4283312   811441          Soccer - Non Regulation  2024-12-31T22:00:00.000
# 4283313   811441          Soccer - Non Regulation  2024-12-31T22:00:00.000
#
#                    end_date_time      event_agency     event_type  \
# 0        2024-01-01T00:10:00.000  Parks Department  Special Event
# 1        2024-01-01T01:00:00.000  Parks Department  Special Event
# 2        2024-01-01T23:59:00.000  Parks Department  Special Event
# 3        2024-01-01T23:00:00.000  Parks Department  Special Event
# 4        2024-01-01T23:59:00.000  Parks Department  Special Event
# ...                          ...               ...            ...
# 4283309  2024-12-31T23:00:00.000  Parks Department  Sport - Youth
# 4283310  2024-12-31T23:00:00.000  Parks Department  Sport - Adult
# 4283311  2024-12-31T23:00:00.000  Parks Department  Sport - Adult
# 4283312  2024-12-31T23:00:00.000  Parks Department  Sport - Adult
# 4283313  2024-12-31T23:00:00.000  Parks Department  Sport - Adult
#
#         event_borough                                     event_location  \
# 0            Brooklyn                   Prospect Park: Long Meadow North
# 1           Manhattan  Central Park: Cherry Hill ,Central Park: Wagne...
# 2           Manhattan                      Central Park: Mineral Springs
# 3           Manhattan           Central Park: Dana Discovery Center Lawn
# 4           Manhattan  Damrosch Park: Bandshell ,Damrosch Park: Tent ...
# ...               ...                                                ...
# 4283309      Brooklyn  Leif Ericson Park: Dust Bowl - Soccer/Football-01
# 4283310      Brooklyn                           McCarren Park: Soccer-01
# 4283311      Brooklyn                           McCarren Park: Soccer-01
# 4283312      Brooklyn                           McCarren Park: Soccer-01
# 4283313      Brooklyn                           McCarren Park: Soccer-01
#
#         street_closure_type community_board police_precinct event_street_side
# 0                       N/A             55,             78,               NaN
# 1                       N/A             64,             22,               NaN
# 2                       N/A             64,             22,               NaN
# 3                       N/A             64,             22,               NaN
# 4                       N/A              7,             20,               NaN
# ...                     ...             ...             ...               ...
# 4283309                 N/A             10,             68,               NaN
# 4283310                 N/A             01,             94,               NaN
# 4283311                 N/A             01,             94,               NaN
# 4283312                 N/A             01,             94,               NaN
# 4283313                 N/A             01,             94,               NaN
#
# [4283314 rows x 12 columns]

# %%
# ========================================
# 4. EXPLORE EVENTS DATA
# ========================================

print("🔍 Exploring Events Dataset...")
print(f"Total events loaded: {len(events_results_df):,}")
print(f"\nColumns available:")
print(events_results_df.columns.tolist())
print(f"\nFirst few rows:")
print(events_results_df.head())
print(f"\nData types:")
print(events_results_df.dtypes)

# Check for event names/categories
if 'event_name' in events_results_df.columns:
    print(f"\nSample event names:")
    print(events_results_df['event_name'].head(20))
elif 'event_type' in events_results_df.columns:
    print(f"\nSample event types:")
    print(events_results_df['event_type'].value_counts().head(20))
# Out:
# 🔍 Exploring Events Dataset...
# Total events loaded: 4,283,314
#
# Columns available:
# ['event_id', 'event_name', 'start_date_time', 'end_date_time', 'event_agency', 'event_type', 'event_borough', 'event_location', 'street_closure_type', 'community_board', 'police_precinct', 'event_street_side']
#
# First few rows:
#   event_id                       event_name          start_date_time  \
# 0   746721  New Years Eve Fireworks Display  2024-01-01T00:00:00.000
# 1   739793       Lawn closure - Cherry Hill  2024-01-01T00:00:00.000
# 2   739847   Lawn Closure - Mineral Springs  2024-01-01T00:00:00.000
# 3   679798      Landscape closed for season  2024-01-01T00:00:00.000
# 4   743992                 Big Apple Circus  2024-01-01T00:00:00.000
#
#              end_date_time      event_agency     event_type event_borough  \
# 0  2024-01-01T00:10:00.000  Parks Department  Special Event      Brooklyn
# 1  2024-01-01T01:00:00.000  Parks Department  Special Event     Manhattan
# 2  2024-01-01T23:59:00.000  Parks Department  Special Event     Manhattan
# 3  2024-01-01T23:00:00.000  Parks Department  Special Event     Manhattan
# 4  2024-01-01T23:59:00.000  Parks Department  Special Event     Manhattan
#
#                                       event_location street_closure_type  \
# 0                   Prospect Park: Long Meadow North                 N/A
# 1  Central Park: Cherry Hill ,Central Park: Wagne...                 N/A
# 2                      Central Park: Mineral Springs                 N/A
# 3           Central Park: Dana Discovery Center Lawn                 N/A
# 4  Damrosch Park: Bandshell ,Damrosch Park: Tent ...                 N/A
#
#   community_board police_precinct event_street_side
# 0             55,             78,               NaN
# 1             64,             22,               NaN
# 2             64,             22,               NaN
# 3             64,             22,               NaN
# 4              7,             20,               NaN
#
# Data types:
# event_id               object
# event_name             object
# start_date_time        object
# end_date_time          object
# event_agency           object
# event_type             object
# event_borough          object
# event_location         object
# street_closure_type    object
# community_board        object
# police_precinct        object
# event_street_side      object
# dtype: object
#
# Sample event names:
# 0                    New Years Eve Fireworks Display
# 1                         Lawn closure - Cherry Hill
# 2                     Lawn Closure - Mineral Springs
# 3                        Landscape closed for season
# 4                                   Big Apple Circus
# 5                           Lawn closure - Pond Lawn
# 6     Lawn closure - Lawn Outside Levin Playground A
# 7                                   Big Apple Circus
# 8                       Bowling Greet Christmas Tree
# 9      Lawn closed for the season-Harlem Meer picnic
# 10                Lawn closure - Lawn behind the MET
# 11                            Lawn closed for season
# 12                    Lawn closure - Diana Ross Lawn
# 13               Catholic League Creche Display 2023
# 14                              MAYORS LAWN BLOCKAGE
# 15                           Lawn closure - East 106
# 16                          Lawn closure - Dene Lawn
# 17                         Lawn closure - East Green
# 18                  Landscape closed for season date
# 19                    Lawn closure - Great Hill Oval
# Name: event_name, dtype: object

# %%
# ========================================
# 5. EXTRACT 5 MAJOR EVENTS FROM REAL DATA
# ========================================

# Convert start_date_time to datetime
events_results_df['start_datetime'] = pd.to_datetime(events_results_df['start_date_time'])
events_results_df['event_date'] = events_results_df['start_datetime'].dt.date

print("🔍 Searching for 5 major events in real data...")

# Define search patterns for each event
event_searches = {
    'Halloween': ['halloween', 'trick or treat'],
    'Thanksgiving': ['thanksgiving', 'macy'],
    'Independence_Day': ['independence', 'july 4', 'firework', 'fourth of july'],
    'New_Years_Eve': ['new year', 'nye'],
    'NYC_Marathon': ['marathon', 'tcs']
}

# Collect all matched events
all_matches = []

for event_category, search_terms in event_searches.items():
    # Search in event_name column (case insensitive)
    pattern = '|'.join(search_terms)
    mask = events_results_df['event_name'].str.lower().str.contains(pattern, na=False)
    matches = events_results_df[mask].copy()
    
    if len(matches) > 0:
        print(f"\n✅ Found {len(matches)} matches for {event_category}:")
        print(matches[['event_name', 'start_datetime', 'event_location']].head(5))
        
        # Add category label
        matches['event_category'] = event_category.replace('_', ' ')
        all_matches.append(matches)
    else:
        print(f"\n⚠️ No matches found for {event_category}")

# Combine all matches into single dataframe
if all_matches:
    df_events = pd.concat(all_matches, ignore_index=True)
    
    # Keep only relevant columns
    df_events = df_events[[
        'event_name', 'event_category', 'event_date', 'start_datetime',
        'event_location', 'event_agency', 'event_type', 'event_borough'
    ]]
    
    print("\n" + "="*60)
    print("FINAL EVENTS DATASET (df_events)")
    print("="*60)
    print(f"Total events extracted: {len(df_events)}")
    print(f"\nEvents by category:")
    print(df_events['event_category'].value_counts())
    print("="*60)
else:
    print("\n❌ No events found!")
    df_events = pd.DataFrame()

# Display dataframe
df_events.head(20)
# Out:
# 🔍 Searching for 5 major events in real data...
#
# ✅ Found 2262 matches for Halloween:
#                                     event_name      start_datetime  \
# 2898675  Brooklyn Scouts Youth Halloween Party 2024-09-22 14:00:00
# 2898751  Brooklyn Scouts Youth Halloween Party 2024-09-22 14:00:00
# 2898754  Brooklyn Scouts Youth Halloween Party 2024-09-22 14:00:00
# 2898757  Brooklyn Scouts Youth Halloween Party 2024-09-22 14:00:00
# 2898760  Brooklyn Scouts Youth Halloween Party 2024-09-22 14:00:00
#
#                                             event_location
# 2898675  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 2898751  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 2898754  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 2898757  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 2898760  Prospect Park: Grecian Shelter/Peristyle Lawn ...
#
# ✅ Found 2262 matches for Halloween:
#                                     event_name      start_datetime  \
# 2898675  Brooklyn Scouts Youth Halloween Party 2024-09-22 14:00:00
# 2898751  Brooklyn Scouts Youth Halloween Party 2024-09-22 14:00:00
# 2898754  Brooklyn Scouts Youth Halloween Party 2024-09-22 14:00:00
# 2898757  Brooklyn Scouts Youth Halloween Party 2024-09-22 14:00:00
# 2898760  Brooklyn Scouts Youth Halloween Party 2024-09-22 14:00:00
#
#                                             event_location
# 2898675  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 2898751  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 2898754  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 2898757  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 2898760  Prospect Park: Grecian Shelter/Peristyle Lawn ...
#
# ✅ Found 777 matches for Thanksgiving:
#                                          event_name      start_datetime  \
# 383491  2024 Macys Flower Show - Production Parking 2024-03-13 00:01:00
# 383492  2024 Macys Flower Show - Production Parking 2024-03-13 00:01:00
# 383493  2024 Macys Flower Show - Production Parking 2024-03-13 00:01:00
# 383494  2024 Macys Flower Show - Production Parking 2024-03-13 00:01:00
# 383495  2024 Macys Flower Show - Production Parking 2024-03-13 00:01:00
#
#                                         event_location
# 383491  WEST   35 STREET between 7 AVENUE and BROADWAY
# 383492  WEST   35 STREET between 7 AVENUE and BROADWAY
# 383493  WEST   35 STREET between 7 AVENUE and BROADWAY
# 383494  WEST   35 STREET between 7 AVENUE and BROADWAY
# 383495  WEST   35 STREET between 7 AVENUE and BROADWAY
#
# ✅ Found 777 matches for Thanksgiving:
#                                          event_name      start_datetime  \
# 383491  2024 Macys Flower Show - Production Parking 2024-03-13 00:01:00
# 383492  2024 Macys Flower Show - Production Parking 2024-03-13 00:01:00
# 383493  2024 Macys Flower Show - Production Parking 2024-03-13 00:01:00
# 383494  2024 Macys Flower Show - Production Parking 2024-03-13 00:01:00
# 383495  2024 Macys Flower Show - Production Parking 2024-03-13 00:01:00
#
#                                         event_location
# 383491  WEST   35 STREET between 7 AVENUE and BROADWAY
# 383492  WEST   35 STREET between 7 AVENUE and BROADWAY
# 383493  WEST   35 STREET between 7 AVENUE and BROADWAY
# 383494  WEST   35 STREET between 7 AVENUE and BROADWAY
# 383495  WEST   35 STREET between 7 AVENUE and BROADWAY
#
# ✅ Found 1415 matches for Independence_Day:
#                            event_name      start_datetime  \
# 0     New Years Eve Fireworks Display 2024-01-01 00:00:00
# 879        Midnight Run and Fireworks 2024-01-01 00:00:00
# 910        Midnight Run and Fireworks 2024-01-01 00:00:00
# 941        Midnight Run and Fireworks 2024-01-01 00:00:00
# 4397  New Years Eve Fireworks Display 2024-01-01 23:59:00
#
#                                          event_location
# 0                      Prospect Park: Long Meadow North
# 879   Central Park: Cherry Hill ,Central Park: Wagne...
# 910   Central Park: Cherry Hill ,Central Park: Wagne...
# 941   Central Park: Cherry Hill ,Central Park: Wagne...
# 4397                   Prospect Park: Long Meadow North
#
# ✅ Found 1415 matches for Independence_Day:
#                            event_name      start_datetime  \
# 0     New Years Eve Fireworks Display 2024-01-01 00:00:00
# 879        Midnight Run and Fireworks 2024-01-01 00:00:00
# 910        Midnight Run and Fireworks 2024-01-01 00:00:00
# 941        Midnight Run and Fireworks 2024-01-01 00:00:00
# 4397  New Years Eve Fireworks Display 2024-01-01 23:59:00
#
#                                          event_location
# 0                      Prospect Park: Long Meadow North
# 879   Central Park: Cherry Hill ,Central Park: Wagne...
# 910   Central Park: Cherry Hill ,Central Park: Wagne...
# 941   Central Park: Cherry Hill ,Central Park: Wagne...
# 4397                   Prospect Park: Long Meadow North
#
# ✅ Found 774 matches for New_Years_Eve:
#                                 event_name      start_datetime  \
# 0          New Years Eve Fireworks Display 2024-01-01 00:00:00
# 1303  sri chinmoy new year's half marathon 2024-01-01 08:00:00
# 1304  sri chinmoy new year's half marathon 2024-01-01 08:00:00
# 1305  sri chinmoy new year's half marathon 2024-01-01 08:00:00
# 1306  sri chinmoy new year's half marathon 2024-01-01 08:00:00
#
#                                          event_location
# 0                      Prospect Park: Long Meadow North
# 1303  Flushing Meadows Corona Park: Around the Unisp...
# 1304  Flushing Meadows Corona Park: Around the Unisp...
# 1305  Flushing Meadows Corona Park: Around the Unisp...
# 1306  Flushing Meadows Corona Park: Around the Unisp...
#
# ✅ Found 774 matches for New_Years_Eve:
#                                 event_name      start_datetime  \
# 0          New Years Eve Fireworks Display 2024-01-01 00:00:00
# 1303  sri chinmoy new year's half marathon 2024-01-01 08:00:00
# 1304  sri chinmoy new year's half marathon 2024-01-01 08:00:00
# 1305  sri chinmoy new year's half marathon 2024-01-01 08:00:00
# 1306  sri chinmoy new year's half marathon 2024-01-01 08:00:00
#
#                                          event_location
# 0                      Prospect Park: Long Meadow North
# 1303  Flushing Meadows Corona Park: Around the Unisp...
# 1304  Flushing Meadows Corona Park: Around the Unisp...
# 1305  Flushing Meadows Corona Park: Around the Unisp...
# 1306  Flushing Meadows Corona Park: Around the Unisp...
#
# ✅ Found 3415 matches for NYC_Marathon:
#                                 event_name      start_datetime  \
# 1303  sri chinmoy new year's half marathon 2024-01-01 08:00:00
# 1304  sri chinmoy new year's half marathon 2024-01-01 08:00:00
# 1305  sri chinmoy new year's half marathon 2024-01-01 08:00:00
# 1306  sri chinmoy new year's half marathon 2024-01-01 08:00:00
# 1307  sri chinmoy new year's half marathon 2024-01-01 08:00:00
#
#                                          event_location
# 1303  Flushing Meadows Corona Park: Around the Unisp...
# 1304  Flushing Meadows Corona Park: Around the Unisp...
# 1305  Flushing Meadows Corona Park: Around the Unisp...
# 1306  Flushing Meadows Corona Park: Around the Unisp...
# 1307  Flushing Meadows Corona Park: Around the Unisp...
#
# ============================================================
# FINAL EVENTS DATASET (df_events)
# ============================================================
# Total events extracted: 8643
#
# Events by category:
# event_category
# NYC Marathon        3415
# Halloween           2262
# Independence Day    1415
# Thanksgiving         777
# New Years Eve        774
# Name: count, dtype: int64
# ============================================================
#
# ✅ Found 3415 matches for NYC_Marathon:
#                                 event_name      start_datetime  \
# 1303  sri chinmoy new year's half marathon 2024-01-01 08:00:00
# 1304  sri chinmoy new year's half marathon 2024-01-01 08:00:00
# 1305  sri chinmoy new year's half marathon 2024-01-01 08:00:00
# 1306  sri chinmoy new year's half marathon 2024-01-01 08:00:00
# 1307  sri chinmoy new year's half marathon 2024-01-01 08:00:00
#
#                                          event_location
# 1303  Flushing Meadows Corona Park: Around the Unisp...
# 1304  Flushing Meadows Corona Park: Around the Unisp...
# 1305  Flushing Meadows Corona Park: Around the Unisp...
# 1306  Flushing Meadows Corona Park: Around the Unisp...
# 1307  Flushing Meadows Corona Park: Around the Unisp...
#
# ============================================================
# FINAL EVENTS DATASET (df_events)
# ============================================================
# Total events extracted: 8643
#
# Events by category:
# event_category
# NYC Marathon        3415
# Halloween           2262
# Independence Day    1415
# Thanksgiving         777
# New Years Eve        774
# Name: count, dtype: int64
# ============================================================
#                                event_name event_category  event_date  \
# 0   Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 1   Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 2   Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 3   Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 4   Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 5   Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 6   Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 7   Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 8   Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 9   Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 10  Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 11  Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 12  Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 13  Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 14  Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 15  Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 16  Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 17  Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 18  Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 19  Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
#
#         start_datetime                                     event_location  \
# 0  2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 1  2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 2  2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 3  2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 4  2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 5  2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 6  2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 7  2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 8  2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 9  2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 10 2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 11 2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 12 2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 13 2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 14 2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 15 2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 16 2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 17 2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 18 2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 19 2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
#
#         event_agency     event_type event_borough
# 0   Parks Department  Special Event      Brooklyn
# 1   Parks Department  Special Event      Brooklyn
# 2   Parks Department  Special Event      Brooklyn
# 3   Parks Department  Special Event      Brooklyn
# 4   Parks Department  Special Event      Brooklyn
# 5   Parks Department  Special Event      Brooklyn
# 6   Parks Department  Special Event      Brooklyn
# 7   Parks Department  Special Event      Brooklyn
# 8   Parks Department  Special Event      Brooklyn
# 9   Parks Department  Special Event      Brooklyn
# 10  Parks Department  Special Event      Brooklyn
# 11  Parks Department  Special Event      Brooklyn
# 12  Parks Department  Special Event      Brooklyn
# 13  Parks Department  Special Event      Brooklyn
# 14  Parks Department  Special Event      Brooklyn
# 15  Parks Department  Special Event      Brooklyn
# 16  Parks Department  Special Event      Brooklyn
# 17  Parks Department  Special Event      Brooklyn
# 18  Parks Department  Special Event      Brooklyn
# 19  Parks Department  Special Event      Brooklyn

# %%
df_events
# Out:
#                                  event_name event_category  event_date  \
# 0     Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 1     Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 2     Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 3     Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# 4     Brooklyn Scouts Youth Halloween Party      Halloween  2024-09-22
# ...                                     ...            ...         ...
# 8638                  CDP Marathon Protests   NYC Marathon  2024-12-03
# 8639                Guadalupe Marathon 2024   NYC Marathon  2024-12-07
# 8640                Guadalupe Marathon 2024   NYC Marathon  2024-12-07
# 8641                Guadalupe Marathon 2024   NYC Marathon  2024-12-07
# 8642                Guadalupe Marathon 2024   NYC Marathon  2024-12-07
#
#           start_datetime                                     event_location  \
# 0    2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 1    2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 2    2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 3    2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# 4    2024-09-22 14:00:00  Prospect Park: Grecian Shelter/Peristyle Lawn ...
# ...                  ...                                                ...
# 8638 2024-12-03 13:30:00         Dag Hammarskjold Plaza: First Avenue Plaza
# 8639 2024-12-07 14:00:00  173 EAST    3 STREET,173 EAST    3 STREET,173 ...
# 8640 2024-12-07 14:00:00  173 EAST    3 STREET,173 EAST    3 STREET,173 ...
# 8641 2024-12-07 14:00:00  173 EAST    3 STREET,173 EAST    3 STREET,173 ...
# 8642 2024-12-07 14:00:00  173 EAST    3 STREET,173 EAST    3 STREET,173 ...
#
#            event_agency     event_type event_borough
# 0      Parks Department  Special Event      Brooklyn
# 1      Parks Department  Special Event      Brooklyn
# 2      Parks Department  Special Event      Brooklyn
# 3      Parks Department  Special Event      Brooklyn
# 4      Parks Department  Special Event      Brooklyn
# ...                 ...            ...           ...
# 8638   Parks Department  Special Event     Manhattan
# 8639  Police Department         Parade     Manhattan
# 8640  Police Department         Parade     Manhattan
# 8641  Police Department         Parade     Manhattan
# 8642  Police Department         Parade     Manhattan
#
# [8643 rows x 8 columns]
